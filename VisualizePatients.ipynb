# %% [markdown]
# # Medical Report Data Analysis and Visualization

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8')
import seaborn as sns
sns.set()  # This applies Seaborn's default style to your plots


# Set style
sns.set_palette('husl')

# Load the JSON data
with open('processed_patients.json', 'r') as f:
    data = json.load(f)

# Create DataFrame
df = pd.DataFrame(data)
df['birth_date'] = pd.to_datetime(df['birth_date'], format='%d.%m.%Y')
print('Data loaded successfully!')
df.head()
# Out:
# Data loaded successfully!
#      tumor_status ecog birth_date             name  gender  \
# 0  cT2b, cNx, cM1    1 1712-01-08       Asoka Tano  female
# 1   cT4, Nx, cM1b  2-3 1955-06-15      Hans Müller    male
# 2  cT4, cN0, cM1b  NaN 1988-06-15  Gertrude Müller  female
# 3   cT4, cN0, cM0    1 1962-03-15    Peter Schmidt  female
# 4    T4, cN2, cM0    2 1965-04-12    Michael Weber    male
#
#              source_file
# 0  Patient Anonymous.txt
# 1           Sample 1.txt
# 2           Sample 2.txt
# 3           Sample 3.txt
# 4           Sample 4.txt

# %% [markdown]
# # Patient Data Analysis

# %%
# Basic Statistics
print(f"Total number of patients: {len(df)}\n")

# Gender distribution
plt.figure(figsize=(10, 5))
gender_counts = df['gender'].value_counts()
sns.barplot(x=gender_counts.index, y=gender_counts.values)
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

print("\nGender Distribution:")
print(gender_counts)
# Out:
# Total number of patients: 9
# g:\Anaconda\envs\federated_learning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# g:\Anaconda\envs\federated_learning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# g:\Anaconda\envs\federated_learning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# Gender Distribution:
# gender
# female    5
# male      4
# Name: count, dtype: int64

# %% [markdown]
# # ECOG Score Analysis

# %%
# ECOG Score Distribution
plt.figure(figsize=(10, 5))
ecog_counts = df['ecog'].value_counts().sort_index()
sns.barplot(x=ecog_counts.index, y=ecog_counts.values)
plt.title('ECOG Score Distribution')
plt.xlabel('ECOG Score')
plt.ylabel('Count')
plt.show()

print("\nECOG Score Distribution:")
print(ecog_counts)
# Out:
# g:\Anaconda\envs\federated_learning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# g:\Anaconda\envs\federated_learning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# g:\Anaconda\envs\federated_learning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ECOG Score Distribution:
# ecog
# 1      2
# 2      1
# 2-3    1
# 4      1
# Name: count, dtype: int64

# %% [markdown]
# # Birth Year Analysis

# %%
# Birth Year Distribution
plt.figure(figsize=(12, 6))
df['birth_year'] = df['birth_date'].dt.year
sns.histplot(data=df, x='birth_year', bins=20)
plt.title('Birth Year Distribution')
plt.xlabel('Birth Year')
plt.ylabel('Count')
plt.show()

print("\nBirth Year Statistics:")
print(df['birth_year'].describe())
# Out:
# g:\Anaconda\envs\federated_learning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# g:\Anaconda\envs\federated_learning\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# Birth Year Statistics:
# count       9.000000
# mean     1927.777778
# std        86.144904
# min      1712.000000
# 25%      1955.000000
# 50%      1962.000000
# 75%      1965.000000
# max      1988.000000
# Name: birth_year, dtype: float64

# %% [markdown]
# # Tumor Status Analysis

# %%
# Tumor Status Distribution
plt.figure(figsize=(12, 6))
tumor_counts = df['tumor_status'].value_counts()
sns.barplot(x=tumor_counts.index, y=tumor_counts.values)
plt.title('Tumor Status Distribution')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

print("\nTumor Status Distribution:")
print(tumor_counts)
# Out:
# g:\Anaconda\envs\federated_learning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# g:\Anaconda\envs\federated_learning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# g:\Anaconda\envs\federated_learning\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# C:\Users\maria\AppData\Local\Temp\ipykernel_3668\101132416.py:7: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# Tumor Status Distribution:
# tumor_status
# cT4, cN0, cM1b    2
# cT2b, cNx, cM1    1
# cT4, Nx, cM1b     1
# cT4, cN0, cM0     1
# T4, cN2, cM0      1
# cT2 cN2 cM0       1
# ...

# %% [markdown]
# # Full Patient Data Overview

# %%
# Configure display options for full patient list
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)

# Display full patient data
df
# Out:
#      tumor_status ecog birth_date             name  gender  \
# 0  cT2b, cNx, cM1    1 1712-01-08       Asoka Tano  female
# 1   cT4, Nx, cM1b  2-3 1955-06-15      Hans Müller    male
# 2  cT4, cN0, cM1b  NaN 1988-06-15  Gertrude Müller  female
# 3   cT4, cN0, cM0    1 1962-03-15    Peter Schmidt  female
# 4    T4, cN2, cM0    2 1965-04-12    Michael Weber    male
# 5     cT2 cN2 cM0  NaN 1955-06-15    Thomas Müller    male
# 6  pT1b pN0 MX R0  NaN 1962-01-14      Marie Curie  female
# 7  cT3, cN3, cM1c    4 1970-06-10   Mildred Scheel  female
# 8  cT4, cN0, cM1b  NaN 1881-08-19  Konrad Adenauer    male
#
#              source_file
# 0  Patient Anonymous.txt
# 1           Sample 1.txt
# 2           Sample 2.txt
# 3           Sample 3.txt
# 4           Sample 4.txt
# 5           Sample 5.txt
# 6           Sample 6.txt
# 7           Sample 7.txt
# 8      Sample Spende.txt
